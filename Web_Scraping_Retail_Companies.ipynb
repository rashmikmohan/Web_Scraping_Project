# %%
from bs4 import BeautifulSoup
import requests

# %%
url='https://en.wikipedia.org/wiki/List_of_largest_retail_companies'
page=requests.get(url)
soup=BeautifulSoup (page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of largest retail companies - Wikipedia</title>
# ...

# %%
table=soup.find('table')

# %%
soup.find_all('table')[0]
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Dominant operational format
# </th>
# <th>Retail revenue <br/>(US$ millions)
# </th>
# <th>Net profit margin
# </th>
# <th colspan="2">Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td>Hypermarket/Supercenter/Superstore
# </td>
# <td>559,151
# </td>
# <td>2.5%</td>
# <td><a href="/wiki/Bentonville,_Arkansas" title="Bentonville, Arkansas">Bentonville</a>
# </td>
# ...

# %%
table = soup.find_All('table')[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 table = soup.find_All('table')[0]
#
# TypeError: 'NoneType' object is not callable

# %%
soup.find ('table', class_='wikitable sortable')
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Dominant operational format
# </th>
# <th>Retail revenue <br/>(US$ millions)
# </th>
# <th>Net profit margin
# </th>
# <th colspan="2">Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td>Hypermarket/Supercenter/Superstore
# </td>
# <td>559,151
# </td>
# <td>2.5%</td>
# <td><a href="/wiki/Bentonville,_Arkansas" title="Bentonville, Arkansas">Bentonville</a>
# </td>
# ...

# %%
soup.find('table', class_='wikitable sortable')
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Dominant operational format
# </th>
# <th>Retail revenue <br/>(US$ millions)
# </th>
# <th>Net profit margin
# </th>
# <th colspan="2">Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td>Hypermarket/Supercenter/Superstore
# </td>
# <td>559,151
# </td>
# <td>2.5%</td>
# <td><a href="/wiki/Bentonville,_Arkansas" title="Bentonville, Arkansas">Bentonville</a>
# </td>
# ...

# %%
soup.find('table')
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Dominant operational format
# </th>
# <th>Retail revenue <br/>(US$ millions)
# </th>
# <th>Net profit margin
# </th>
# <th colspan="2">Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td>Hypermarket/Supercenter/Superstore
# </td>
# <td>559,151
# </td>
# <td>2.5%</td>
# <td><a href="/wiki/Bentonville,_Arkansas" title="Bentonville, Arkansas">Bentonville</a>
# </td>
# ...

# %%
print(table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Dominant operational format
# </th>
# <th>Retail revenue <br/>(US$ millions)
# </th>
# <th>Net profit margin
# </th>
# <th colspan="2">Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td>Hypermarket/Supercenter/Superstore
# </td>
# <td>559,151
# </td>
# <td>2.5%</td>
# <td><a href="/wiki/Bentonville,_Arkansas" title="Bentonville, Arkansas">Bentonville</a>
# </td>
# ...

# %%
world_titles=table.find_all('th')

# %%
world_titles
# Out:
# [<th>Rank
#  </th>,
#  <th>Name
#  </th>,
#  <th>Dominant operational format
#  </th>,
#  <th>Retail revenue <br/>(US$ millions)
#  </th>,
#  <th>Net profit margin
#  </th>,
#  <th colspan="2">Headquarters
#  </th>]

# %%
world_table_titles = [ title.text.strip() for title in world_titles]
print (world_table_titles)
# Out:
# ['Rank', 'Name', 'Dominant operational format', 'Retail revenue (US$ millions)', 'Net profit margin', 'Headquarters']

# %%
import pandas as pd

# %%
df=pd.DataFrame (columns=world_table_titles)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Dominant operational format, Retail revenue (US$ millions), Net profit margin, Headquarters]
# Index: []

# %%
column_data=table.find_all('tr')

# %%
for row in column_data [1:]:
    row_data=row.find_all('td')
    individual_row_data=[data.text.strip() for data in row_data]
    #print (individual_row_data)
    #length =len(df)
    #df.loc[length]=individual_row_data

for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    if len(individual_row_data) == len(df.columns):
        length = len(df)
        df.loc[length] = individual_row_data
    else:
        print(f"Skipping row due to mismatched columns: {individual_row_data}")
# Out:
# Skipping row due to mismatched columns: ['1', 'Walmart', 'Hypermarket/Supercenter/Superstore', '559,151', '2.5%', 'Bentonville', 'United States']
# Skipping row due to mismatched columns: ['2', 'Amazon', 'Non-store (E-commerce)', '213,573', '5.5%', 'Seattle', 'United States']
# Skipping row due to mismatched columns: ['3', 'Costco', 'Cash & Carry/Warehouse Club', '166,761', '2.4%', 'Issaquah', 'United States']
# Skipping row due to mismatched columns: ['4', 'Schwarz Gruppe', 'Discount store', '167,200', '...', 'Neckarsulm', 'Germany']
# Skipping row due to mismatched columns: ['5', 'The Home Depot', 'Home improvement', '132,110', '9.7%', 'Atlanta', 'United States']
# Skipping row due to mismatched columns: ['6', 'The Kroger Company', 'Supermarket', '131,620', '2.0%', 'Cincinnati', 'United States']
# Skipping row due to mismatched columns: ['7', 'Walgreens Boots Alliance', 'Drug store/Pharmacy', '117,705', '0.3%', 'Deerfield', 'United States']
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Dominant operational format, Retail revenue (US$ millions), Net profit margin, Headquarters]
# Index: []

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    # Debug print to check lengths
    print(f"individual_row_data length: {len(individual_row_data)}, df columns length: {len(df.columns)}")
    print(f"individual_row_data: {individual_row_data}")

    if len(individual_row_data) == len(df.columns):
        length = len(df)
        df.loc[length] = individual_row_data
    else:
        print(f"Skipping row due to mismatched columns: {individual_row_data}")

print(df)
# Out:
# individual_row_data length: 7, df columns length: 6
# individual_row_data: ['1', 'Walmart', 'Hypermarket/Supercenter/Superstore', '559,151', '2.5%', 'Bentonville', 'United States']
# Skipping row due to mismatched columns: ['1', 'Walmart', 'Hypermarket/Supercenter/Superstore', '559,151', '2.5%', 'Bentonville', 'United States']
# individual_row_data length: 7, df columns length: 6
# individual_row_data: ['2', 'Amazon', 'Non-store (E-commerce)', '213,573', '5.5%', 'Seattle', 'United States']
# Skipping row due to mismatched columns: ['2', 'Amazon', 'Non-store (E-commerce)', '213,573', '5.5%', 'Seattle', 'United States']
# individual_row_data length: 7, df columns length: 6
# individual_row_data: ['3', 'Costco', 'Cash & Carry/Warehouse Club', '166,761', '2.4%', 'Issaquah', 'United States']
# Skipping row due to mismatched columns: ['3', 'Costco', 'Cash & Carry/Warehouse Club', '166,761', '2.4%', 'Issaquah', 'United States']
# individual_row_data length: 7, df columns length: 6
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Dominant operational format, Retail revenue (US$ millions), Net profit margin, Headquarters]
# Index: []

# %%
df['Country'] = ''

# %%
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Dominant operational format, Retail revenue (US$ millions), Net profit margin, Headquarters, Country]
# Index: []

# %%
for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]

    # Debug print to check lengths
    print(f"individual_row_data length: {len(individual_row_data)}, df columns length: {len(df.columns)}")
    print(f"individual_row_data: {individual_row_data}")

    if len(individual_row_data) == len(df.columns):
        length = len(df)
        df.loc[length] = individual_row_data
    else:
        print(f"Skipping row due to mismatched columns: {individual_row_data}")

print(df)
# Out:
# individual_row_data length: 7, df columns length: 7
# individual_row_data: ['1', 'Walmart', 'Hypermarket/Supercenter/Superstore', '559,151', '2.5%', 'Bentonville', 'United States']
# individual_row_data length: 7, df columns length: 7
# individual_row_data: ['2', 'Amazon', 'Non-store (E-commerce)', '213,573', '5.5%', 'Seattle', 'United States']
# individual_row_data length: 7, df columns length: 7
# individual_row_data: ['3', 'Costco', 'Cash & Carry/Warehouse Club', '166,761', '2.4%', 'Issaquah', 'United States']
# individual_row_data length: 7, df columns length: 7
# individual_row_data: ['4', 'Schwarz Gruppe', 'Discount store', '167,200', '...', 'Neckarsulm', 'Germany']
# individual_row_data length: 7, df columns length: 7
# individual_row_data: ['5', 'The Home Depot', 'Home improvement', '132,110', '9.7%', 'Atlanta', 'United States']
# individual_row_data length: 7, df columns length: 7
# ...

# %%
df
# Out:
#    Rank               Name         Dominant operational format  \
# 0     1            Walmart  Hypermarket/Supercenter/Superstore
# 1     2             Amazon              Non-store (E-commerce)
# 2     3             Costco         Cash & Carry/Warehouse Club
# 3     4     Schwarz Gruppe                      Discount store
# 4     5     The Home Depot                    Home improvement
# ..  ...                ...                                 ...
# 95   96             Kering          Apparel/Footwear specialty
# 96   97  Dm-drogerie markt                 Drug store/Pharmacy
# 97   98    El Corte Inglés                    Department store
# 98   99            Coupang                           Non-store
# 99  100             Hy-Vee                         Supermarket
#
#    Retail revenue (US$ millions) Net profit margin     Headquarters  \
# 0                        559,151              2.5%      Bentonville
# 1                        213,573              5.5%          Seattle
# ...

# %%
df.to_csv(r'C:\Users\rkrishnamohan\OneDrive - United Way Centraide Windsor-Essex County\Desktop\Hackforge\Web Scraping\Top_100_Retail_Companies.csv',index=False)
